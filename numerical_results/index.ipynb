# %% [markdown]
# # Numerical Comparisons
#
# This page contains information to reproduce the numerical comparisons made in SuSiE manuscript. Note that the DSC benchmark has to be completed at this stage.
# Please [follow these instructions](../DSC.html) to run the DSC benchmark for SuSiE fine-mapping applications. The benchmark is computationally intensive due to some of the methods compared.
# If you do not want to rerun the benchmark yourself but only to reproduce our comparison figure and tables, you can [download the data here](https://shiny.stephenslab.uchicago.edu/html/). Data file directory should look like:
#
# ```
# .
# ├── hard_case
# ├── susie_comparison
# ```

# %%
%revisions -s -n 10
# Out:
#         <table class="revision_table">
#         <tr>
#         <th>Revision</th>
#         <th>Author</th>
#         <th>Date</th>
#         <th>Message</th>
#         <tr>
#         <tr><td><a target="_blank" href="http://github.com/stephenslab/susie-paper/blob/280347deae3c267cef3fa39637b910a3a3735b7f/numerical_results/index.ipynb"><span class="revision_id">280347d<span></a></td>
# <td>Gao Wang</td>
# <td>2018-08-09</td>
# <td>susie results with prior 0.1, susieR version 0.2.0</td></tr><tr><td><a target="_blank" href="http://github.com/stephenslab/susie-paper/blob/25886dcb9e559823bff62fc3671ed5da76c2f1f1/numerical_results/index.ipynb"><span class="revision_id">25886dc<span></a></td>
# <td>Gao Wang</td>
# <td>2018-08-06</td>
# <td>Add Figs 1 to 3</td></tr><tr><td><a target="_blank" href="http://github.com/stephenslab/susie-paper/blob/35d7c5be745f4e8bc43c88b2c41450da72ae007f/numerical_results/index.ipynb"><span class="revision_id">35d7c5b<span></a></td>
# <td>Gao Wang</td>
# <td>2018-08-06</td>
# <td>Rename Yang's data page</td></tr><tr><td><a target="_blank" href="http://github.com/stephenslab/susie-paper/blob/2bf5d87ee9f4bceba5682bef0438d5a11bb076a7/numerical_results/index.ipynb"><span class="revision_id">2bf5d87<span></a></td>
# <td>Gao Wang</td>
# <td>2018-08-06</td>
# <td>Add index pages</td></tr></table>

# %% [markdown]
# ## Figure 1: PIP calibration

# %% [markdown]
# ### Command
#
# ```
# sos run analysis/20180527_PIP_Workflow.ipynb cali_pip
# ```
#
# ### Result

# %%
%preview susie_comparison/PIP_comparison_0722.calibrated.estvar_true.png
# Out:
# <div class="sos_hint">%preview susie_comparison/PIP_comparison_0722.calibrated.estvar_true.png</div>
# > susie_comparison/PIP_comparison_0722.calibrated.estvar_true.png (296.3 KiB):

# %% [markdown]
# ## Figure 2: Variable level power comparison

# %% [markdown]
# ### Command
#
# ```
# sos run analysis/20180527_PIP_Workflow.ipynb roc
# ```
#
# ### Result

# %%
%preview susie_comparison/ROC_0722.png
# Out:
# <div class="sos_hint">%preview susie_comparison/ROC_0722.png</div>
# > susie_comparison/ROC_0722.png (481.4 KiB):

# %% [markdown]
# ## Figure 3: "Purity" distribution

# %% [markdown]
# ### Command
#
# ```
# sos run analysis/20180620_Purity_Plot_Lite.ipynb purity
# ```
#
# ### Result

# %%
%preview susie_comparison/hist_0722.png
# Out:
# <div class="sos_hint">%preview susie_comparison/hist_0722.png</div>
# > susie_comparison/hist_0722.png (13.4 KiB):

# %% [markdown]
# ## Figure S2: Purity vs size illustration

# %%
%preview susie_comparison/purity_0722/7.png
# Out:
# <div class="sos_hint">%preview susie_comparison/purity_0722/7.png</div>
# > susie_comparison/purity_0722/7.png (346.8 KiB):

# %% [markdown]
# ## Figure 4: Power comparisons of confidence sets
#
# For "simple case" simulation: number of causal is 1 - 5.
#
# ### Command
#
# ```
# sos run analysis/20180527_PIP_Workflow.ipynb power
# sos run analysis/20180615_Power_DAP.ipynb power
# ```
#
# ### Result

# %%
readRDS('susie_comparison/Power_comparison_0722_cluster_prob_estvar_true.rds')
# Out:
#   n_signal expected_discoveries susie_discoveries dap_discoveries susie_power
# 1 1         300                 304               270             0.9633333
# 2 2         600                 429               391             0.6616667
# 3 3         900                 528               468             0.5455556
# 4 4        1200                 607               530             0.4625000
# 5 5        1500                 621               533             0.3813333
#   dap_power susie_fdp  dap_fdp     susie_avg_size dap_avg_size
# 1 0.8933333 0.04934211 0.007407407  9.712803       6.05597
# 2 0.6016667 0.07692308 0.081841432 14.866162       8.10585
# 3 0.4866667 0.08901515 0.087606838 16.646570      10.43560
# 4 0.4033333 0.11532125 0.105660377 15.327747      11.14979
# 5 0.3233333 0.13204509 0.127579737 18.972171      12.32473
#   susie_median_size dap_median_size susie_avg_ld dap_avg_ld
# 1 2                 3               0.9928653    0.9882466
# 2 4                 5               0.9823747    0.9712244
# 3 5                 7               0.9720828    0.9607073
# 4 6                 8               0.9695598    0.9485908
# 5 6                 9               0.9645615    0.9503371

# %%
readRDS('hard_case/DAP_comparison_0801_cluster_prob_estvar_true.rds')
# Out:
#    n_signal expected_discoveries susie_discoveries dap_discoveries susie_power
# 10 10       3000                 945               848             0.2796667
#    dap_power susie_fdp dap_fdp   susie_avg_size dap_avg_size susie_median_size
# 10 0.2406667 0.1259259 0.1580189 23.75908       12.77871     7
#    dap_median_size susie_avg_ld dap_avg_ld
# 10 10              0.9390865    0.8983109

# %% [markdown]
# ## Figure S1 & S2: PIP comparison

# %% [markdown]
# ### Command
#
# ```
# sos run analysis/20180527_PIP_Workflow.ipynb pip
# ```
#
# ### Result
#
# SuSiE vs DAP-G

# %%
%preview susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.susie_vs_dap.png
# Out:
# <div class="sos_hint">%preview susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.susie_vs_dap.png</div>
# > susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.susie_vs_dap.png (126.1 KiB):

# %% [markdown]
# SuSiE vs CAVIAR

# %%
%preview susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.susie_vs_caviar.png
# Out:
# <div class="sos_hint">%preview susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.susie_vs_caviar.png</div>
# > susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.susie_vs_caviar.png (111.3 KiB):

# %% [markdown]
# SuSiE vs FINEMAP

# %%
%preview ~/GIT/github/mvarbvs/dsc/susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.susie_vs_finemap.png
# Out:
# <div class="sos_hint">%preview ~/GIT/github/mvarbvs/dsc/susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.susie_vs_finemap.png</div>
# > /home/gaow/GIT/github/mvarbvs/dsc/susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.susie_vs_finemap.png (109.7 KiB):

# %% [markdown]
# DAP vs CAVIAR

# %%
%preview susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.dap_vs_caviar.png
# Out:
# <div class="sos_hint">%preview susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.dap_vs_caviar.png</div>
# > susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.dap_vs_caviar.png (111.9 KiB):

# %% [markdown]
# DAP vs FINEMAP

# %%
%preview susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.dap_vs_finemap.png
# Out:
# <div class="sos_hint">%preview susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.dap_vs_finemap.png</div>
# > susie_comparison/PIP_comparison_0722_estvar_true_filter_true_0p5.dap_vs_finemap.png (109.6 KiB):

# %% [markdown]
# To consolidate these figures:

# %%
cd ~/GIT/github/mvarbvs/dsc/susie_comparison
d=0722
convert -append PIP_comparison_"$d"_estvar_true_filter_true_0p5.susie_vs_dap.png PIP_comparison_"$d"_estvar_true_filter_true_0p5.susie_vs_caviar.png PIP_comparison_"$d"_estvar_true_filter_true_0p5.susie_vs_finemap.png PIP_comparison_"$d"_susie_vs_others.png
convert -append PIP_comparison_"$d"_estvar_true_filter_true_0p5.dap_vs_caviar.png PIP_comparison_"$d"_estvar_true_filter_true_0p5.dap_vs_finemap.png PIP_comparison_"$d"_estvar_true_filter_true_0p5.caviar_vs_finemap.png PIP_comparison_"$d"_others.png

# %% [markdown]
# ## Figure S3
#
# ### Command
#
# ```
# sos run analysis/20180620_Purity_Plot_Lite.ipynb ld
# ```
#
# ### Result

# %%
%preview susie_comparison/ld_0622.png
# Out:
# <div class="sos_hint">%preview susie_comparison/ld_0622.png</div>
# > susie_comparison/ld_0622.png (93.0 KiB):

# %% [markdown]
# ## Table S1

# %% [markdown]
# ### Command
#
# ```
# sos run analysis/20180527_PIP_Workflow.ipynb coverage
# ```
#
# ### Result

# %%
print_summary = function(dat) {
    res = c(0,0)
    for (level in c(0.01, 0.05, 0.1, 0.15, 0.2, 0.25)) {
        s = as.character(level*100)
        d = do.call(rbind, lapply(1:length(dat), function(i) dat[[as.character(i)]][[s]]))
        d = colSums(d)
        res = rbind(res, c(level, d[2]/(d[1]+d[2])))
    }
    res = data.frame(res[-1,])
    colnames(res) = c ('1 - coverage', 'false discovery proportion')
    res
}
dat = readRDS('susie_comparison/Coverage_0722_estvar_true.rds')
print_summary(dat)
# Out:
#   1 - coverage false discovery proportion
# 1 0.01         0.03103044
# 2 0.05         0.06090808
# 3 0.10         0.08690929
# 4 0.15         0.12019231
# 5 0.20         0.15481833
# 6 0.25         0.17784711

# %%
dat = readRDS('susie_comparison/Coverage_0722_estvar_false.rds')
print_summary(dat)
# Out:
#   1 - coverage false discovery proportion
# 1 0.01         0.02545003
# 2 0.05         0.03995300
# 3 0.10         0.05758267
# 4 0.15         0.08000000
# 5 0.20         0.10746102
# 6 0.25         0.13734142
